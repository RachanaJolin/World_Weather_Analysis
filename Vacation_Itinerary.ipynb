# %%
# Import the random module.
import random 
# Import the NumPy module.
import numpy as np
# Import timeit.
import timeit

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 11.5 µs ± 169 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(x):
    latitudes = []
    while x < 1501:
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with x = 1.
# %timeit latitudes(1)
# Out:
# 1.7 ms ± 341 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 621

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2542cf2578abf24fac37456405279597

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Lompoc"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
print (city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2542cf2578abf24fac37456405279597&q=Lompoc

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
#city_url = url + "&q=" + "Chicago"
#city_weather = requests.get(city_url)
#city_weather

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-120.46,"lat":34.64},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}],"base":"stations","main":{"temp":48.61,"pressure":1020,"humidity":65,"temp_min":44.6,"temp_max":53.01},"visibility":16093,"wind":{"speed":11.41,"deg":100,"gust":16.11},"clouds":{"all":90},"dt":1575133568,"sys":{"type":1,"id":4558,"country":"US","sunrise":1575125391,"sunset":1575161492},"timezone":-28800,"id":5367788,"name":"Lompoc","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -120.46, 'lat': 34.64},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 48.61,
#   'pressure': 1020,
#   'humidity': 65,
#   'temp_min': 44.6,
#   'temp_max': 53.01},
#  'visibility': 16093,
#  'wind': {'speed': 11.41, 'deg': 100, 'gust': 16.11},
#  'clouds': {'all': 90},
#  'dt': 1575133568,
#  'sys': {'type': 1,
#   'id': 4558,
#   'country': 'US',
#   'sunrise': 1575125391,
#   'sunset': 1575161492},
#  'timezone': -28800,
#  'id': 5367788,
#  'name': 'Lompoc',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
#city_url = url + "&q=" + "Chicago"
#city_weather = requests.get(city_url)
#if city_weather.status_code == 200:
   # print(f"City Weather found.")
#else:
  #  print(f"City weather not found.")

# %%
# Get the JSON data.
chi_data = city_weather.json()

# %%
lat = chi_data["coord"]["lat"]
lng = chi_data["coord"]["lon"]
max_temp = chi_data["main"]["temp_max"]
humidity = chi_data["main"]["humidity"]
clouds = chi_data["clouds"]["all"]
wind = chi_data["wind"]["speed"]
#rain=chi_data["main"]["rain"]
#rain= chi_data["rain"]["1h"]
#snow=chi_data["main"]["snow"]


print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 34.64 -120.46 53.01 65 90 11.41

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = chi_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2019-11-30 17:06:08'

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city
    if i>100:
        break

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1     
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        #Current_Description = city_weather ["main"] ["description"]
        #city_rain = city_weather["rain"]["3h"]
        #city_snow =city_weather["snow"]["1h"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        try:
            city_rain = city_weather["rain"]["3h"]
        except:
            city_rain = 0
        try:
            city_snow = city_weather["snow"]["3h"]
        except:
            city_snow = 0
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                         "Rain":city_rain,
                          "Snow":city_snow,
                          "Country": city_country,
                          "Date": city_date})
                        # "Current Description":Current_Description})

# If an error is experienced, skip the city.
    except:
      print("City not found. Skipping...")
    pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | bulawayo
# Processing Record 2 of Set 1 | new norfolk
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | mar del plata
# Processing Record 5 of Set 1 | mount pleasant
# Processing Record 6 of Set 1 | namatanai
# Processing Record 7 of Set 1 | nyurba
# Processing Record 8 of Set 1 | liverpool
# Processing Record 9 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 1 | huarmey
# Processing Record 11 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 1 | longyearbyen
# Processing Record 13 of Set 1 | yumen
# Processing Record 14 of Set 1 | vostok
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | nikolskoye
# ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(50)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Bulawayo -20.16   28.59     80.87        15           7        9.24
# 1      New Norfolk -42.78  147.06     50.00        53          90        9.17
# 2          Mataura -46.19  168.86     54.00        83          77        1.99
# 3    Mar Del Plata -46.43  -67.52     60.87        30          56       13.58
# 4   Mount Pleasant  33.16  -94.97     75.99        69          75       11.41
# 5        Namatanai  -3.66  152.44     82.98        70          70        6.60
# 6           Nyurba  63.29  118.35     -3.86        97         100        5.50
# 7        Liverpool  53.41   -2.98     39.00        93           0       11.41
# 8          Huarmey -10.07  -78.15     80.73        43          12       11.72
# 9     Longyearbyen  78.22   15.63     12.20        43         100       28.86
# 10           Yumen  40.29   97.04     17.89        36           0       11.48
# ...

# %%
New_Column_Order=["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed", "Rain","Snow"]
city_data_df=city_data_df[New_Column_Order]
city_data_df.head(10)
# Out:
#              City Country                 Date    Lat     Lng  Max Temp  \
# 0        Bulawayo      ZW  2019-11-30 17:06:42 -20.16   28.59     80.87
# 1     New Norfolk      AU  2019-11-30 17:00:14 -42.78  147.06     50.00
# 2         Mataura      NZ  2019-11-30 17:00:21 -46.19  168.86     54.00
# 3   Mar Del Plata      AR  2019-11-30 17:00:27 -46.43  -67.52     60.87
# 4  Mount Pleasant      US  2019-11-30 17:06:43  33.16  -94.97     75.99
# 5       Namatanai      PG  2019-11-30 17:06:43  -3.66  152.44     82.98
# 6          Nyurba      RU  2019-11-30 17:06:43  63.29  118.35     -3.86
# 7       Liverpool      GB  2019-11-30 17:01:55  53.41   -2.98     39.00
# 8         Huarmey      PE  2019-11-30 17:06:44 -10.07  -78.15     80.73
# 9    Longyearbyen      NO  2019-11-30 17:00:15  78.22   15.63     12.20
#
#    Humidity  Cloudiness  Wind Speed  Rain  Snow
# 0        15           7        9.24   0.0   0.0
# 1        53          90        9.17   0.0   0.0
# ...

# %%
# Create the output file (CSV).
output_data_file = "weather_data/vacation_Challenge2.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1575133624.35068

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)]
city_data_df.head(5)
# Out:
#              City Country                 Date    Lat     Lng  Max Temp  \
# 0        Bulawayo      ZW  2019-11-30 17:06:42 -20.16   28.59     80.87
# 1     New Norfolk      AU  2019-11-30 17:00:14 -42.78  147.06     50.00
# 2         Mataura      NZ  2019-11-30 17:00:21 -46.19  168.86     54.00
# 3   Mar Del Plata      AR  2019-11-30 17:00:27 -46.43  -67.52     60.87
# 4  Mount Pleasant      US  2019-11-30 17:06:43  33.16  -94.97     75.99
#
#    Humidity  Cloudiness  Wind Speed  Rain  Snow
# 0        15           7        9.24   0.0   0.0
# 1        53          90        9.17   0.0   0.0
# 2        83          77        1.99   0.0   0.0
# 3        30          56       13.58   0.0   0.0
# 4        69          75       11.41   0.0   0.0

# %%
index13 =city_data_df.loc[13]
index13
# Out:
# City                    Cape Town
# Country                        ZA
# Date          2019-11-30 17:00:03
# Lat                        -33.93
# Lng                         18.42
# Max Temp                     69.8
# Humidity                       49
# Cloudiness                     33
# Wind Speed                  12.75
# Rain                            0
# Snow                            0
# Name: 13, dtype: object

# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import gmaps.datasets
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df.to_csv("weather_data/vacation_cities.csv",index=False)
city_data_df = pd.read_csv("weather_data/vacation_cities.csv")
city_data_df.head()
# Out:
#              City Country                 Date    Lat     Lng  Max Temp  \
# 0        Bulawayo      ZW  2019-11-30 17:06:42 -20.16   28.59     80.87
# 1     New Norfolk      AU  2019-11-30 17:00:14 -42.78  147.06     50.00
# 2         Mataura      NZ  2019-11-30 17:00:21 -46.19  168.86     54.00
# 3   Mar Del Plata      AR  2019-11-30 17:00:27 -46.43  -67.52     60.87
# 4  Mount Pleasant      US  2019-11-30 17:06:43  33.16  -94.97     75.99
#
#    Humidity  Cloudiness  Wind Speed  Rain  Snow
# 0        15           7        9.24   0.0   0.0
# 1        53          90        9.17   0.0   0.0
# 2        83          77        1.99   0.0   0.0
# 3        30          56       13.58   0.0   0.0
# 4        69          75       11.41   0.0   0.0

# %%
# Get the data types.
city_data_df.dtypes
# Out:
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Rain          float64
# Snow          float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of temperature
# 1. Assign the locations to an array of latitude and longitude pairs.
locations = city_data_df[["Lat", "Lng"]]
# 2. Assign the weights variable to some values.
max_temp = city_data_df["Max Temp"]
# 3. Assign the figure variable to the gmaps.figure() attribute.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# 4. Assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations.
heatmap_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp],dissipating=False, max_intensity=300, point_radius=4) #[max(0,temp) for temp in max_temp])

# 5. Add the heatmap layer.
fig.add_layer(heatmap_layer)
# 6. Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent cloudiness
locations = city_data_df[["Lat", "Lng"]]
cloudiness = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=cloudiness, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent windspeed
locations = city_data_df[["Lat", "Lng"]]
cloudiness = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=cloudiness, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 50
# What is the maximum temperature you would like for your trip? 85

# %%
# Ask the customer if they want rain or snow
min_rain = input("Do you want it to be raining? (yes/no) ")
min_snow = input("Do you want it to be snowing? (yes/no) ")
# Out:
# Do you want it to be raining? (yes/no) no
# Do you want it to be snowing? (yes/no) no

# %%
# Filter the dataset to find the cities that fit the criteria.
#preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       #(city_data_df["Max Temp"] >= min_temp)]
#preferred_cities_df.head(10)
# Out:
#   File "<ipython-input-44-1e42b2c48aeb>", line 3
#     (city_data_df["Max Temp"] >= min_temp)]
#     ^
# IndentationError: unexpected indent

# %%
#preferred_cities_df = No rain, No snow
if min_rain == "no" and min_snow == "no":
    # Filter the dataset to find the cities that fit the criteria.
    preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & 
                                       (city_data_df["Max Temp"] >= min_temp)& 
                                       (city_data_df["Rain"] == 0) & 
                                       (city_data_df["Snow"] == 0)]
preferred_cities_df.head(10)
# Out:
#               City Country                 Date    Lat     Lng  Max Temp  \
# 0         Bulawayo      ZW  2019-11-30 17:06:42 -20.16   28.59     80.87
# 1      New Norfolk      AU  2019-11-30 17:00:14 -42.78  147.06     50.00
# 2          Mataura      NZ  2019-11-30 17:00:21 -46.19  168.86     54.00
# 3    Mar Del Plata      AR  2019-11-30 17:00:27 -46.43  -67.52     60.87
# 4   Mount Pleasant      US  2019-11-30 17:06:43  33.16  -94.97     75.99
# 5        Namatanai      PG  2019-11-30 17:06:43  -3.66  152.44     82.98
# 8          Huarmey      PE  2019-11-30 17:06:44 -10.07  -78.15     80.73
# 12    Punta Arenas      CL  2019-11-30 17:00:00 -53.16  -70.91     55.40
# 13       Cape Town      ZA  2019-11-30 17:00:03 -33.93   18.42     69.80
# 14           Kapaa      US  2019-11-30 17:00:17  22.08 -159.32     77.00
#
#     Humidity  Cloudiness  Wind Speed  Rain  Snow
# 0         15           7        9.24   0.0   0.0
# 1         53          90        9.17   0.0   0.0
# ...

# %%
# Filter the dataset to find the cities that fit the criteria.
YESRAINNOSNOWpreferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & 
                                       (city_data_df["Max Temp"] >= min_temp)& 
                                       (city_data_df["Rain"] > 0) & 
                                       (city_data_df["Snow"] == 0)]
YESRAINNOSNOWpreferred_cities_df.head(10)
# Out:
#             City Country                 Date    Lat     Lng  Max Temp  \
# 35        Lucapa      AO  2019-11-30 17:06:50  -8.42   20.74     70.97
# 69  Ponta Do Sol      BR  2019-11-30 17:06:59 -20.63  -46.00     79.09
# 78     Tuatapere      NZ  2019-11-30 17:07:01 -46.13  167.69     54.00
# 79          Abha      SA  2019-11-30 17:07:01  18.22   42.50     64.40
#
#     Humidity  Cloudiness  Wind Speed  Rain  Snow
# 35        91          94        2.66  1.38   0.0
# 69        73          96        6.06  3.63   0.0
# 78        83         100        1.99  0.44   0.0
# 79        82          38        2.80  0.19   0.0

# %%
# Filter the dataset to find the cities that fit the criteria.
NORAINYESSNOWpreferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & 
                                       (city_data_df["Max Temp"] >= min_temp)& 
                                       (city_data_df["Rain"] == 0) & 
                                       (city_data_df["Snow"] > 0)]
NORAINYESSNOWpreferred_cities_df.head(50)
# Out:
# Empty DataFrame
# Columns: [City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Rain, Snow]
# Index: []

# %%
# Filter the dataset to find the cities that fit the criteria.
YESRAINYESSNOWpreferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & 
                                       (city_data_df["Max Temp"] >= min_temp)& 
                                       (city_data_df["Rain"] > 0) & 
                                       (city_data_df["Snow"] == 0)]
YESRAINYESSNOWpreferred_cities_df.head(10)
# Out:
#             City Country                 Date    Lat     Lng  Max Temp  \
# 35        Lucapa      AO  2019-11-30 17:06:50  -8.42   20.74     70.97
# 69  Ponta Do Sol      BR  2019-11-30 17:06:59 -20.63  -46.00     79.09
# 78     Tuatapere      NZ  2019-11-30 17:07:01 -46.13  167.69     54.00
# 79          Abha      SA  2019-11-30 17:07:01  18.22   42.50     64.40
#
#     Humidity  Cloudiness  Wind Speed  Rain  Snow
# 35        91          94        2.66  1.38   0.0
# 69        73          96        6.06  3.63   0.0
# 78        83         100        1.99  0.44   0.0
# 79        82          38        2.80  0.19   0.0

# %%
preferred_cities_df.count()
# Out:
# City          47
# Country       46
# Date          47
# Lat           47
# Lng           47
# Max Temp      47
# Humidity      47
# Cloudiness    47
# Wind Speed    47
# Rain          47
# Snow          47
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#               City Country  Max Temp    Lat     Lng Hotel Name
# 0         Bulawayo      ZW     80.87 -20.16   28.59
# 1      New Norfolk      AU     50.00 -42.78  147.06
# 2          Mataura      NZ     54.00 -46.19  168.86
# 3    Mar Del Plata      AR     60.87 -46.43  -67.52
# 4   Mount Pleasant      US     75.99  33.16  -94.97
# 5        Namatanai      PG     82.98  -3.66  152.44
# 8          Huarmey      PE     80.73 -10.07  -78.15
# 12    Punta Arenas      CL     55.40 -53.16  -70.91
# 13       Cape Town      ZA     69.80 -33.93   18.42
# 14           Kapaa      US     77.00  22.08 -159.32
# 15           Vaini      IN     69.64  15.34   74.49
# 17           Ancud      CL     55.40 -41.87  -73.83
# 18       Pringsewu      ID     72.54  -5.36  104.98
# 19         Tucuman      PE     72.70 -17.17  -70.89
# 21          Hobart      AU     50.00 -42.88  147.33
# 23    Kruisfontein      ZA     59.58 -34.00   24.73
# 25           Adrar      DZ     80.60  27.87   -0.29
# ...

# %%
# Dependencies and Setup
import requests
import gmaps

# Import API key
from config import g_key# Set parameters to search for a hotel.

params = {
    "radius": 20000,
    "type": "lodging",
    "key": g_key
}

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

# %%
#hotels

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to the params dictionary as values to the location key.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
  # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df
# Out:
#               City Country  Max Temp    Lat     Lng  \
# 0         Bulawayo      ZW     80.87 -20.16   28.59
# 1      New Norfolk      AU     50.00 -42.78  147.06
# 2          Mataura      NZ     54.00 -46.19  168.86
# 3    Mar Del Plata      AR     60.87 -46.43  -67.52
# 4   Mount Pleasant      US     75.99  33.16  -94.97
# 5        Namatanai      PG     82.98  -3.66  152.44
# 8          Huarmey      PE     80.73 -10.07  -78.15
# 12    Punta Arenas      CL     55.40 -53.16  -70.91
# 13       Cape Town      ZA     69.80 -33.93   18.42
# 14           Kapaa      US     77.00  22.08 -159.32
# 15           Vaini      IN     69.64  15.34   74.49
# 17           Ancud      CL     55.40 -41.87  -73.83
# 18       Pringsewu      ID     72.54  -5.36  104.98
# 19         Tucuman      PE     72.70 -17.17  -70.89
# 21          Hobart      AU     50.00 -42.88  147.33
# 23    Kruisfontein      ZA     59.58 -34.00   24.73
# 25           Adrar      DZ     80.60  27.87   -0.29
# ...

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Store the Hotel CSV you saved created in part one into a DataFrame.
hotel_df.to_csv("weather_data/WeatherPy_vacation.csv",index=False)
hotel_df = pd.read_csv("weather_data/WeatherPy_vacation.csv")
hotel_df.head()
# Out:
#              City Country  Max Temp    Lat     Lng  \
# 0        Bulawayo      ZW     80.87 -20.16   28.59
# 1     New Norfolk      AU     50.00 -42.78  147.06
# 2         Mataura      NZ     54.00 -46.19  168.86
# 3   Mar Del Plata      AR     60.87 -46.43  -67.52
# 4  Mount Pleasant      US     75.99  33.16  -94.97
#
#                                     Hotel Name
# 0                     4 On Housman Backpackers
# 1              The Shingles Riverside Cottages
# 2                                Ellie's Villa
# 3                      Hotel Costanera Del Sur
# 4  Holiday Inn Express & Suites Mount Pleasant

# %%
hotel_df
# Out:
#               City Country  Max Temp    Lat     Lng  \
# 0         Bulawayo      ZW     80.87 -20.16   28.59
# 1      New Norfolk      AU     50.00 -42.78  147.06
# 2          Mataura      NZ     54.00 -46.19  168.86
# 3    Mar Del Plata      AR     60.87 -46.43  -67.52
# 4   Mount Pleasant      US     75.99  33.16  -94.97
# 5        Namatanai      PG     82.98  -3.66  152.44
# 6          Huarmey      PE     80.73 -10.07  -78.15
# 7     Punta Arenas      CL     55.40 -53.16  -70.91
# 8        Cape Town      ZA     69.80 -33.93   18.42
# 9            Kapaa      US     77.00  22.08 -159.32
# 10           Vaini      IN     69.64  15.34   74.49
# 11           Ancud      CL     55.40 -41.87  -73.83
# 12       Pringsewu      ID     72.54  -5.36  104.98
# 13         Tucuman      PE     72.70 -17.17  -70.89
# 14          Hobart      AU     50.00 -42.88  147.33
# 15    Kruisfontein      ZA     59.58 -34.00   24.73
# 16           Adrar      DZ     80.60  27.87   -0.29
# ...

# %%
#PART 3 of Challenge
import gmaps
import gmaps.datasets
gmaps.configure(g_key)
VacationCities_df = pd.read_csv("weather_data/Directions_Cities.csv")
VacationCities_df
# Out:
#            City Country              Date    Lat    Lng  Max Temp  Humidity  \
# 0    Bredasdorp      ZA  11/30/2019 17:06 -34.53  20.04     71.60        46
# 1      Hermanus      ZA  11/30/2019 17:00 -34.42  19.24     66.99        73
# 2  Kruisfontein      ZA  11/30/2019 17:06 -34.00  24.73     59.58        80
# 3     Cape Town      ZA  11/30/2019 17:00 -33.93  18.42     69.80        49
#
#    Cloudiness  Wind Speed  Rain  Snow
# 0          32       17.22     0     0
# 1           8        5.99     0     0
# 2          70       10.87     0     0
# 3          33       12.75     0     0

# %%
#PART 3 of Challenge
import gmaps
import gmaps.datasets
gmaps.configure(g_key)
Bredasdorp= (34.53,20.04)
Hermanus=(-34.42,19.24)
Kruisfontein=(-34.00,24.73)
CapeTown=(-33.93,18.42)




fig = gmaps.figure()
Cities = gmaps.directions_layer(Bredasdorp,Hermanus) 
Cities = gmaps.directions_layer(Hermanus,CapeTown)
Cities = gmaps.directions_layer(CapeTown,Kruisfontein)

fig.add_layer(Cities) 
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
